# %%
import math
import numpy as np
from scipy.special import binom as binom_c
from scipy.special import comb
from scipy.stats import beta
from scipy.stats import binom

# %% [markdown]
# # CREATING A BINOMIAL PROBABILITY DISTRIBUTION

# %% [markdown]
# Calculating probability of flipping exactly 12 heads in 24 coin tosses

# %% [markdown]
# general equation: Binomial(k;n,p) = **Binomial_Coefficient(n, k) x p^k x (1 - p)^n-k**
#
# where:
#
# k = number of outcomes we care about
# n = number of total trials
# p = probability of event happening

# %% [markdown]
# Let's look how we can calculate whole equation using binomial coefficient (binom_c) and other variables, and then using scipy function instead

# %%
p = 0.5
n = 24
k = 12

# %%
binom_c(n, k) * (p**k) * ((1 - p)**(n-k))
# Out:
# 0.1611802577972412

# %% [markdown]
# which can be calculated with this function as well:
#
# Probability Mass Function (PMF)

# %%
binom.pmf(k=k, n=n, p=p)
# Out:
# 0.16118025779724182

# %% [markdown]
# If we need to calculate the probability of interval though, we would use sf function, for instance the probability of getting at least one outcome in 100 trails with probability of 0.00720

# %%
p = 0.00720
k = 0
n = 100

# %%
binom.sf(k=k, n=n, p=p)
# Out:
# 0.5145138452542948

# %% [markdown]
# ## EXERCISES

# %% [markdown]
# ### 1. What are the parameters of the binomial distribution for the probability of rolling either a 1 or a 20 on a 20-sided die, if we roll the die 12 times?

# %%
p = 0.1
n = 12
k = 1

# %%
binom.pmf(k=k, n=n, p=p)
# Out:
# 0.3765727153079992

# %% [markdown]
# ### 2. There are four aces in a deck of 52 cards. If you pull a card, return the card, then reshuffle and pull a card again, how many ways can you pull just one ace in five pulls?

# %%
comb(5, 1, exact=True)
# Out:
# 5

# %% [markdown]
# ### 3. For example in question 2, what is the probability of pulling five aces in 10 pulls (remember the card is shuffled back in the deck when it is pulled)?

# %%
p = 4/52
n = 10
k = 5

# %%
binom.pmf(k=k, n=n, p=p)
# Out:
# 0.0004548552879040868

# %% [markdown]
# ### 4. When you’re searching for a new job, it’s always helpful to have more than one offer on the table so you can use it in negotiations. If you have a 1/5 probability of receiving a job offer when you interview, and you interview with seven companies in a month, what is the probability you’ll have at least two competing offers by the end of that month?

# %%
p = 0.2
n = 7
k = 1

# %%
binom.sf(k=k, n=n, p=p)
# Out:
# 0.42328320000000036

# %% [markdown]
# ### 5. You get a bunch of recruiter emails and find out you have 25 interviews lined up in the next month. Unfortunately, you know this will leave you exhausted, and the probability of getting an offer will drop to 1/10 if you’re tired. You really don’t want to go on this many interviews unless you are at least twice as likely to get at least two competing offers.
# ### Are you more likely to get at least two offers if you go for 25 interviews, or stick to just 7?

# %%
p2 = 0.1
n2 = 25
k2 = 1

# %%
binom.sf(k=k2, n=n2, p=p2)
# Out:
# 0.7287940935386334

# %%
if 2 * (binom.sf(k=k, n=n, p=p)) <= binom.sf(k=k2, n=n2, p=p2):
    print('You should should take 25 interviews, for sure!')
else:
    print(f'You should not take it, the probability is only {(binom.sf(k=k2, n=n2, p=p2))/(binom.sf(k=k, n=n, p=p))}' 
          ' times higher')
# Out:
# You should not take it, the probability is only 1.7217647512082521 times higher
